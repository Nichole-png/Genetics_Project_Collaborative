# %% [markdown]
# # Reading #2
#
# This Berg reading provides you with some background in working with the crystal structure of phenylalanine hydroxylase.  The article contains the crystal structure you will be studying.
#
# REF:
# * Andersen, O.A., et al., “Crystal Structure of … Human Phenylalanine
# Hydroxylase,”  J. Mol. Biol., 320, p. 1095-1108 (2002).
# * Berg JM, Tymoczko JL, Stryer L, Clarke ND. Biochemistry. 5. ed., [Nachdr.], international ed. Freeman; 2003.

# %%
from IPython.display import IFrame
IFrame('https://drive.google.com/file/d/1qZlP65QYaiSrQ_KGdOXeHqsapLCYvXIv/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1qZlP65QYaiSrQ_KGdOXeHqsapLCYvXIv/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Answer the following questions:
# Input your answer in the cell below each question and press SHIFT+ENTER.

# %% [markdown]
# 1. Write the reaction catalyzed by phenylalanine hydroxylase below.  Be sure to draw the chemical structures of phenylalanine and tyrosine.

# %% [markdown]
# Answer here

# %% [markdown]
# 2. Normally, what fraction of phenylalanine is converted into tyrosine?

# %% [markdown]
# Answer here

# %% [markdown]
# 3. Without doing genetic testing, what is an indication that a person is a carrier of the PKU gene?

# %% [markdown]
# Answer here

# %%
IFrame('https://drive.google.com/file/d/1PeAJsRuiZSznP-DcENcfUvItXo1pO1G1/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1PeAJsRuiZSznP-DcENcfUvItXo1pO1G1/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# 4. Describe the crystal structure that was solved for this paper.

# %% [markdown]
# Answer here

# %% [markdown]
# 5. Compare and contrast the structure of the substrate analog with phenylalanine.
# Substrate analog:  3-(2-thienyl)-L-alanine (THA):

# %%
IFrame('https://drive.google.com/file/d/12rGpaCore_UzTBx23PEy8CKIvnrcaTn4/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/12rGpaCore_UzTBx23PEy8CKIvnrcaTn4/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Answer here
