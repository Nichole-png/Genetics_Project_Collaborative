# %% [markdown]
# # Reading #2
#
# This reading will provide you with some background in working with the crystal structure of superoxide dismutase.  The article listed below contains the crystal structure you will be studying.  You need to read just an excerpt from this article. The pages in Stryer are assigned to provide an introduction to superoxide dismutase.
#
# REF:
# * Hart, P.J, et al., “A Structure-Based Mechanism for Copper-Zinc Superoxide
# Dismutase,” Biochemistry, Vol 38, p. 2167 – 2178, (1999).
# * Berg JM, Tymoczko JL, Stryer L, Clarke ND. Biochemistry. 5. ed., [Nachdr.], international ed. Freeman; 2003.

# %%
from IPython.display import IFrame
IFrame('https://drive.google.com/file/d/1pzdR4EdjeOibc1EuRoaoFiWAfsmGAkiv/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1pzdR4EdjeOibc1EuRoaoFiWAfsmGAkiv/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Answer the following questions:
# Input your answer in the cell below each question and press SHIFT+ENTER.

# %% [markdown]
# 1. Describe the three crystal structures that are reported in this article.

# %% [markdown]
# Answer here

# %% [markdown]
# 2. How is superoxide anion produced in organisms?

# %% [markdown]
# Answer here

# %% [markdown]
# 3. Describe the differences between Figure 1 and Figure 2.

# %% [markdown]
# Answer here

# %% [markdown]
# ## Read section 18.3.6

# %%
IFrame('https://drive.google.com/file/d/1s_Tj75z-FsBYFcUl0i0newMRhxTMwGbe/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1s_Tj75z-FsBYFcUl0i0newMRhxTMwGbe/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# 5.  What are reactive oxygen species (ROS)?

# %% [markdown]
# Answer here

# %% [markdown]
# 6. Write the reactions for SOD and catalase.

# %% [markdown]
# Answer here

# %% [markdown]
# 7. What can oxidative damage do?

# %% [markdown]
# Answer here
