# %% [markdown]
# # Reading #2
#
# This reading provides you with some background for working with the crystal structure of a cytochrome P450 enzyme. The abstract summarizes how expression of cytochrome P450 enzymes in lung tissue is related to lung cancer.  The excerpt is for the article that contains the crystal structure you will be studying.
#
# REF:
# * Hukkanen, J., et al, “Expression and regulation of …P450 enzymes in human lung,” Crit Rev Toxicol., 32, p. 391-411 (2002).
#
# * Williams, P.A., et al., “Crystal structure of human cytochrome P450 2C9 with bound warfarin,” Nature, 424, pp. 464 (2003).

# %%
from IPython.display import IFrame
IFrame('https://drive.google.com/file/d/1ZxT1Kvrs8MuIPEj5mPsKwf3adIGVbyAm/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1ZxT1Kvrs8MuIPEj5mPsKwf3adIGVbyAm/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Answer the following questions:
# Input your answer in the cell below each question and press SHIFT+ENTER.

# %% [markdown]
# 1. What types of compounds do cytochrome P450 enzymes metabolize?

# %% [markdown]
# Answer here

# %% [markdown]
# 2. Which CYP isoform was crystallized for this paper and what organism is it from?

# %% [markdown]
# Answer here

# %% [markdown]
# 3. How has the proposed role of Arg 97 changed due to the solving of this crystal structure?

# %% [markdown]
# Answer here

# %%
IFrame('https://drive.google.com/file/d/1QzpWohq3PKK-pX2knzyKs03o3LAQ_ifg/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1QzpWohq3PKK-pX2knzyKs03o3LAQ_ifg/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# 4. Expression of CYP enzymes in what tissue type is discussed in this review?

# %% [markdown]
# Answer here

# %% [markdown]
# 5. What do the authors propose could lead to differing risks for lung cancer for different individuals?

# %% [markdown]
# Answer here

# %% [markdown]
# 6. What isoforms of P450 enzymes were found to be expressed in lung tissue?

# %% [markdown]
# Answer here
