# %% [markdown]
# # Lung Cancer Project: Cytochrome P450 1A1
#
# ## Introduction
#
# It is well known that smoking leads to an increased risk for lung cancer, but how does genetics play into the risk for developing lung cancer?  The transformation of a normal cell into a cancerous cell can result from many causes.  In one model, factors that lead to an increased rate of mutation in DNA increases the chances that a proto-oncogene will be mutated into an oncogene, causing a normal cell to be transformed into a cancerous cell.
#
# Some research has shown an increased incidence for lung cancer in smokers who have a particular polymorphic version of the gene for cytochrome P450 1A1 that is expressed in the cells that line their lungs.
# Cytochrome P450 1A1 (CYP1A1) is an enzyme that oxidizes polycyclic aromatic hydrocarbons (PAHs).  The basic mechanism that has been proposed is that this enzyme converts aromatic hydrocarbons in cigarette smoke into more toxic compounds that can modify DNA and that this leads to a higher rate of mutation in the cells that line the lungs.

# %% [markdown]
# ## Objectives
#
# In this project, you will:
#
# * Examine one gene, cytochrome P450, that has been proposed to be a risk factor for lung cancer. You will be examining a cDNA sequence for this gene that contains a mutation.
#
# * Analyze the mutant protein using bioinformatics tools within Google Colab.
#
# * Investigate the structure of the protein, model the mutation, and find out what is known, if anything, about the biological impact of the mutation.
#
# * Form a hypothesis about what the structural and biological effects are of this mutation.
#
# * Organize the results of your research into a report which you will present at the end of the semester.

# %% [markdown]
# ## Reading #1:
# ## Scientific American article: “Uncovering new clues to cancer risk”:
#
# This first reading provides you
# with a background to genetics and lung cancer. It describes some of the
# molecular changes that have been linked to lung cancer and how identifying
# these changes can lead to better predictions of individual risk.
#
# REF:
# * Perera, F.P., “Uncovering New Clues to Cancer,” Scientific American, May 1996, p. 54 – 62.

# %%
from IPython.display import IFrame
IFrame('https://drive.google.com/file/d/1-rxOVMP3HBmje5Xo89ew9Uh8h6mqsMmN/preview', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://drive.google.com/file/d/1-rxOVMP3HBmje5Xo89ew9Uh8h6mqsMmN/preview"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Answer the following questions.
#
# Input your answer in the cell below each question and press SHIFT+ENTER.

# %% [markdown]
# 1. What does PAH stand for?

# %% [markdown]
# Answer here

# %% [markdown]
# 2. Name two sources for PAHs in our environment.

# %% [markdown]
# Answer here

# %% [markdown]
# 3. Explain how PAH-DNA adducts can lead to cancer.

# %% [markdown]
# Answer here

# %% [markdown]
# 4. Explain how certain forms of CYP1A1 may increase cancer risk.

# %% [markdown]
# Answer here

# %% [markdown]
# 5. List one more “Biomarker for Susceptibility” besides CYP1A1 and explain how inheriting that mutation can lead to cancer.

# %% [markdown]
# Answer here
