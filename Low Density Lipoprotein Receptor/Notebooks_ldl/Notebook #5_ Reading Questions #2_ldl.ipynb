# %% [markdown]
# # Reading #2
#
# This set of readings provides you with some background in working with the crystal structure of the low density lipoprotein receptor.  This article contains the crystal structure you will be studying.
#
# REF:
# * Rudenko, G., et al., “Structure of the LDL Receptor Extracellular Domain at Endosomal pH.” Science, Vol. 298, p. 2353 – 2358, (2002).
# * Berg JM, Tymoczko JL, Stryer L, Clarke ND. Biochemistry. 5. ed., [Nachdr.], international ed. Freeman; 2003.

# %% [markdown]
# **To view the reading, click on the next cell and hit SHIFT+ENTER on your keyboard**

# %%
from IPython.display import IFrame
IFrame('https://drive.google.com/file/d/1aVFPqeAmWoTY_cqqmku2m4fB6WrMOeYc/preview', width=600, height=300)

# %% [markdown]
# In this article, the EGF-domains are referred to as A, B, and C while the blade region is referred to as the “β-propeller.”  The 7 cystein-rich domains are numbered R1 – R7.

# %% [markdown]
# ## Answer the following questions:
# Input your answer in the cell below each question and press SHIFT+ENTER.

# %% [markdown]
# 1. What is the proposed role for the β-propeller?

# %% [markdown]
# Answer here

# %% [markdown]
# 2. What are the roles of R4 and R5?

# %% [markdown]
# Answer here

# %% [markdown]
# **To view the reading, click on the next cell and hit SHIFT+ENTER on your keyboard**

# %%
IFrame('https://drive.google.com/file/d/19VixHpFscwANOtrnPQbEDKFGVmqfmy0u/preview', width=600, height=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9ade83adcd46> in <module>()
# ----> 1 IFrame('https://drive.google.com/file/d/19VixHpFscwANOtrnPQbEDKFGVmqfmy0u/preview', width=600, height=300)
#
# NameError: name 'IFrame' is not defined

# %% [markdown]
# Read Sections 26.3.4 – 26.4

# %% [markdown]
# 3. What region(s) of the LDL receptor bind LDL?

# %% [markdown]
# Answer here

# %% [markdown]
# 4. Describe the role of the calcium ions in LDL binding and/or release.

# %% [markdown]
# Answer here

# %% [markdown]
# 5. In familial hypercholesterolemia, why is the heterozygous state easier to treat than the homozygous state?

# %% [markdown]
# Answer here
